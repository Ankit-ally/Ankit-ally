# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankit-ally/Ankit-ally/blob/main/%E2%80%9CBuilt_an_AI_powered_podcast_automation_system_with_real_time_email_outreach_using_SMTP_and_LLMs_%E2%80%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # 🚀 PROJECT: Automated Podcast Production System (Real Implementation)
# ```BY:-- MR. ANKIT JITENDRA SHARMA

# %% [markdown]
# .
#
# 🧠 🏗️ SYSTEM ARCHITECTURE (REAL)

# %%
# User Input (YouTube Link)
#         ↓
# Channel Analysis (API / Mock)
#         ↓
# Guest Generation (AI logic)
#         ↓
# Outreach Message Generator
#         ↓
# Scheduling Generator
#         ↓
# Research Report Generator
#         ↓
# Dashboard (Streamlit UI)

# %% [markdown]
# 📂 PROJECT STRUCTURE

# %%
# ```
# podcast_automation/
# │
# ├── app.py
# ├── utils/
# │   ├── analyzer.py
# │   ├── guest_finder.py
# │   ├── outreach.py
# │   ├── scheduler.py
# │   ├── research.py
# │
# ├── data/
# │   └── guests.csv
# │
# ├── requirements.txt
# ```

# %%
# !pip install streamlit pandas numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 70.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 99.7 MB/s eta 0:00:00
# ...

# %%
def analyze_channel(link):
    return {
        "topics": ["Business", "Startups", "AI"],
        "audience": "Entrepreneurs",
        "guest_type": "Founders & Creators"
    }

# %%
import pandas as pd

def find_guests():
    data = [
        ["Rahul Sharma", "Instagram", "E-commerce", "200K", "$500K"],
        ["Ankit Jain", "Twitter", "SaaS", "150K", "$1M"]
    ]

    df = pd.DataFrame(data, columns=[
        "Name", "Platform", "Business", "Followers", "Revenue"
    ])
    return df

# %%
def generate_message(name):
    return f"""
Hi {name},

Loved your work! We'd love to invite you to our podcast.

Let us know your availability.

Best,
Podcast Team
"""

# %%
def schedule_meeting(name):
    return {
        "guest": name,
        "date": "2026-04-01",
        "time": "5:00 PM",
        "meeting_link": "https://meet.google.com/demo-link"
    }

# %%
def generate_questions(name):
    return [
        f"What inspired your journey, {name}?",
        "What challenges did you face?",
        "Advice for beginners?"
    ]

# %%
import streamlit as st
# Functions are defined in other cells and are globally available
# from analyzer import analyze_channel
# from guest_finder import find_guests
# from outreach import generate_message
# from scheduler import schedule_meeting
# from research import generate_questions

st.title("🎙️ Podcast Automation System")

link = st.text_input("Enter YouTube Link")

if st.button("Run Automation"):
    # Step 1: Analyze
    analysis = analyze_channel(link)
    st.subheader("📊 Channel Strategy")
    st.write(analysis)

    # Step 2: Guests
    st.subheader("👥 Suggested Guests")
    guests = find_guests()
    st.dataframe(guests)

    # Step 3: Outreach
    st.subheader("📩 Outreach Message")
    msg = generate_message(guests.iloc[0]['Name'])
    st.code(msg)

    # Step 4: Scheduling
    st.subheader("📅 Schedule")
    schedule = schedule_meeting(guests.iloc[0]['Name'])
    st.write(schedule)

    # Step 5: Research
    st.subheader("🧠 Interview Questions")
    questions = generate_questions(guests.iloc[0]['Name'])
    st.write(questions)
# Out:
# 2026-03-22 05:48:22.323 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 05:48:22.436
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-03-22 05:48:22.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 05:48:22.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 05:48:22.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 05:48:22.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 05:48:22.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import matplotlib.pyplot as plt

st.subheader("📈 Workflow Visualization")

steps = ["Analyze", "Guests", "Outreach", "Schedule", "Research"]

plt.figure()
plt.plot(steps, [1,2,3,4,5], marker='o')
plt.title("Podcast Workflow Pipeline")

st.pyplot(plt)
# Out:
# 2026-03-22 05:49:11.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 05:49:11.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 05:49:11.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 05:49:11.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 05:49:12.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 05:49:12.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 05:49:12.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# !streamlit run app.py
# Out:
# Usage: streamlit run [OPTIONS] [TARGET] [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: app.py

# %%
# !mkdir -p utils

# %%
# %%writefile utils/analyzer.py
def analyze_channel(link):
    return {
        "topics": ["Business", "Startups", "AI"],
        "audience": "Entrepreneurs",
        "guest_type": "Founders & Creators"
    }
# Out:
# Writing utils/analyzer.py

# %%
# %%writefile utils/guest_finder.py
import pandas as pd

def find_guests():
    data = [
        ["Rahul Sharma", "Instagram", "E-commerce", "200K", "$500K"],
        ["Ankit Jain", "Twitter", "SaaS", "150K", "$1M"]
    ]

    df = pd.DataFrame(data, columns=[
        "Name", "Platform", "Business", "Followers", "Revenue"
    ])
    return df
# Out:
# Writing utils/guest_finder.py

# %%
# %%writefile utils/outreach.py
def generate_message(name):
    return f"""
Hi {name},

Loved your work! We'd love to invite you to our podcast.

Let us know your availability.

Best,
Podcast Team
"""
# Out:
# Writing utils/outreach.py

# %%
# %%writefile utils/scheduler.py
def schedule_meeting(name):
    return {
        "guest": name,
        "date": "2026-04-01",
        "time": "5:00 PM",
        "meeting_link": "https://meet.google.com/demo-link"
    }
# Out:
# Writing utils/scheduler.py

# %%
# %%writefile utils/research.py
def generate_questions(name):
    return [
        f"What inspired your journey, {name}?",
        "What challenges did you face?",
        "Advice for beginners?"
    ]
# Out:
# Writing utils/research.py

# %%
# %%writefile app.py
import streamlit as st
from utils.analyzer import analyze_channel
from utils.guest_finder import find_guests
from utils.outreach import generate_message
from utils.scheduler import schedule_meeting
from utils.research import generate_questions

st.title("🎙️ Podcast Automation System")

link = st.text_input("Enter YouTube Link")

if st.button("Run Automation"):
    # Step 1: Analyze
    analysis = analyze_channel(link)
    st.subheader("📊 Channel Strategy")
    st.write(analysis)

    # Step 2: Guests
    st.subheader("👥 Suggested Guests")
    guests = find_guests()
    st.dataframe(guests)

    # Step 3: Outreach
    st.subheader("📩 Outreach Message")
    msg = generate_message(guests.iloc[0]['Name'])
    st.code(msg)

    # Step 4: Scheduling
    st.subheader("📅 Schedule")
    schedule = schedule_meeting(guests.iloc[0]['Name'])
    st.write(schedule)

    # Step 5: Research
    st.subheader("🧠 Interview Questions")
    questions = generate_questions(guests.iloc[0]['Name'])
    st.write(questions)
# Out:
# Writing app.py

# %%
# !streamlit run app.py
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.16.220.222:8501
#
#   Stopping...
#   Stopping...

# %% [markdown]
# 🧠 1. ADD OPENAI INTEGRATION (Real AI Brain)

# %%
from openai import OpenAI

client = OpenAI(api_key="YOUR_API_KEY")

def generate_ai_response(prompt):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a professional podcast producer"},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

# %%
# from utils.ai_engine import generate_ai_response

def analyze_channel(link):
    prompt = f"Analyze this YouTube channel and suggest podcast strategy: {link}"
    return generate_ai_response(prompt)

# %%
from utils.ai_engine import generate_ai_response

def generate_message(name):
    prompt = f"Write a personalized podcast invitation message for {name}"
    return generate_ai_response(prompt)

# %%
# %%writefile utils/ai_engine.py
from openai import OpenAI

client = OpenAI(api_key="YOUR_API_KEY")

def generate_ai_response(prompt):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a professional podcast producer"},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content
# Out:
# Writing utils/ai_engine.py

# %%
import os
if not os.path.exists('utils'):
    os.makedirs('utils')
print("Directory 'utils' created if it didn't exist.")
# Out:
# Directory 'utils' created if it didn't exist.

# %%
from utils.ai_engine import generate_ai_response

def generate_questions(name):
    prompt = f"Generate deep podcast interview questions for {name}"
    return generate_ai_response(prompt)

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

from utils.analyzer import analyze_channel
from utils.guest_finder import find_guests
from utils.outreach import generate_message
from utils.scheduler import schedule_meeting
from utils.research import generate_questions

st.set_page_config(page_title="Podcast AI System", layout="wide")

st.title("🎙️ AI Podcast Automation System")
st.markdown("### Automate your entire podcast workflow with AI")

link = st.text_input("🔗 Enter YouTube Channel Link")

if st.button("🚀 Run Full Automation"):
    col1, col2 = st.columns(2)

    with col1:
        st.subheader("📊 Strategy")
        strategy = analyze_channel(link)
        st.write(strategy)

        st.subheader("👥 Guests")
        guests = find_guests()
        st.dataframe(guests)

    with col2:
        st.subheader("📩 Outreach")
        msg = generate_message(guests.iloc[0]['Name'])
        st.success(msg)

        st.subheader("📅 Schedule")
        schedule = schedule_meeting(guests.iloc[0]['Name'])
        st.info(schedule)

    st.subheader("🧠 Interview Questions")
    questions = generate_questions(guests.iloc[0]['Name'])
    st.write(questions)

    # Graph
    st.subheader("📈 Workflow Progress")

    steps = ["Strategy", "Guests", "Outreach", "Schedule", "Research"]
    values = [1, 2, 3, 4, 5]

    plt.figure()
    plt.plot(steps, values, marker='o')
    plt.title("Automation Workflow")

    st.pyplot(plt)
# Out:
# 2026-03-22 06:20:12.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 06:20:12.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 06:20:12.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 06:20:12.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 06:20:12.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 06:20:12.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-22 06:20:12.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# !streamlit run app.py
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/streamlit", line 5, in <module>
#     from streamlit.web.cli import main
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/__init__.py", line 62, in <module>
#     from streamlit import config as _config
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/config.py", line 31, in <module>
#     from streamlit import config_util, development, env_util, file_util, util
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/config_util.py", line 21, in <module>
#     import urllib.request
#   File "/usr/lib/python3.12/urllib/request.py", line 88, in <module>
#     import http.client
#   File "/usr/lib/python3.12/http/client.py", line 1450, in <module>
#     import ssl
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
# ...

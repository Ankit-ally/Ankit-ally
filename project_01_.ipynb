# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankit-ally/Ankit-ally/blob/main/project_01_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MINI PROJECT_01

# %% [markdown]
# Cross Market_Analysis

# %% [markdown]
# Crypto currency

# %%
import requests    # use string formating, and scroll through 5 page to collect data
import pandas as pd

url = "https://api.coingecko.com/api/v3/coins/markets?vs_currency=inr&per_page=250&order=market_cap_desc&page=1&sparkline=False"


response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
data = response.json()
data
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 5901047,
#   'market_cap': 117833282396478,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 117833282396478,
#   'total_volume': 14586154768885,
#   'high_24h': 6476580,
#   'low_24h': 5442845,
#   'price_change_24h': -497401.23612147104,
#   'price_change_percentage_24h': -7.77378,
#   'market_cap_change_24h': -9943707784885.266,
#   'market_cap_change_percentage_24h': -7.78208,
#   'circulating_supply': 19985006.0,
#   'total_supply': 19985021.0,
#   'max_supply': 21000000.0,
#   'ath': 11187013,
#   'ath_change_percentage': -47.25091,
#   'ath_date': '2025-10-06T18:57:42.558Z',
#   'atl': 3993.42,
#   'atl_change_percentage': 147669.28962,
#   'atl_date': '2013-07-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-06T06:42:29.276Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
# ...

# %%
data[0]['id']
# Out:
# 'bitcoin'

# %%
# from the feature last update extract only the date
#pandas datetime module

# %% [markdown]
# Top 3 Coins - Historical prices

# %%
coin_id = "tether"
URL = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart?vs_currency=inr&days=365"
response = requests.get(url)

response.json()               # pandas datetime models convert into milli seconds
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 5870466,
#   'market_cap': 116974165232294,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 116974165232294,
#   'total_volume': 14621546402568,
#   'high_24h': 6476580,
#   'low_24h': 5442845,
#   'price_change_24h': -530522.9098054748,
#   'price_change_percentage_24h': -8.28814,
#   'market_cap_change_24h': -11490447787800.797,
#   'market_cap_change_percentage_24h': -8.94445,
#   'circulating_supply': 19985021.0,
#   'total_supply': 19985021.0,
#   'max_supply': 21000000.0,
#   'ath': 11187013,
#   'ath_change_percentage': -47.52427,
#   'ath_date': '2025-10-06T18:57:42.558Z',
#   'atl': 3993.42,
#   'atl_change_percentage': 146903.50363,
#   'atl_date': '2013-07-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-06T07:07:47.600Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
# ...

# %% [markdown]
# FOR OIL

# %%
import pandas as pd
oil_df = pd.read_csv("https://raw.githubusercontent.com/datasets/oil-prices/main/data/wti-daily.csv")

oil_df.head()
# Out:
#          Date  Price
# 0  1986-01-02  25.56
# 1  1986-01-03  26.00
# 2  1986-01-06  26.53
# 3  1986-01-07  25.85
# 4  1986-01-08  25.87

# %%
##Stock Prices (Yahoo Finance API)

# %%
import yfinance as yf
import pandas as pd

# Choose indices
tickers = ["^GSPC", "^IXIC", "^NSEI"]
start_date = "2020-01-01"
end_date = "2026-01-12"

# Download historical data
stocks_df = yf.download(tickers, start=start_date, end=end_date, group_by="ticker")
stocks_df.head()
# Out:
# /tmp/ipython-input-1369541528.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks_df = yf.download(tickers, start=start_date, end=end_date, group_by="ticker")
# [*********************100%***********************]  3 of 3 completed
# Ticker            ^IXIC                                                       \
# Price              Open         High          Low        Close        Volume
# Date
# 2020-01-01          NaN          NaN          NaN          NaN           NaN
# 2020-01-02  9039.459961  9093.429688  9010.889648  9092.190430  2.862700e+09
# 2020-01-03  8976.429688  9065.759766  8976.429688  9020.769531  2.586520e+09
# 2020-01-06  8943.500000  9072.410156  8943.500000  9071.469727  2.810450e+09
# 2020-01-07  9076.639648  9091.929688  9042.549805  9068.580078  2.381740e+09
#
# Ticker            ^GSPC                                                       \
# ...

# %%
stocks_df['^IXIC'].reset_index() # handle the  nulls    # for the stocks details only for basic understanding implementation part - 01 completed
# Out:
# Price       Date          Open          High           Low         Close  \
# 0     2020-01-01           NaN           NaN           NaN           NaN
# 1     2020-01-02   9039.459961   9093.429688   9010.889648   9092.190430
# 2     2020-01-03   8976.429688   9065.759766   8976.429688   9020.769531
# 3     2020-01-06   8943.500000   9072.410156   8943.500000   9071.469727
# 4     2020-01-07   9076.639648   9091.929688   9042.549805   9068.580078
# ...          ...           ...           ...           ...           ...
# 1558  2026-01-05  23449.669922  23476.509766  23332.230469  23395.820312
# 1559  2026-01-06  23446.960938  23559.150391  23389.570312  23547.169922
# 1560  2026-01-07  23544.890625  23723.369141  23504.210938  23584.279297
# 1561  2026-01-08  23548.880859  23558.169922  23353.460938  23480.019531
# 1562  2026-01-09  23496.210938  23721.150391  23426.480469  23671.349609
#
# Price        Volume
# 0               NaN
# 1      2.862700e+09
# 2      2.586520e+09
# ...

# %% [markdown]
# SQL Connection

# %%
# Jupyter notebook connectoion  and Mysql
# Postgres - psycopg2

# mysql - pymysql or mysql.connector

import pymysql

conn = pymysql.connect(
    host = "localhost",
    port = 3306,
    user = "root",
    password = "Ankit@12345",
)

cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3991680740.py in <cell line: 0>()
#       4 # mysql - pymysql or mysql.connector
#       5
# ----> 6 import pymysql
#       7
#       8 conn = pymysql.connect(
#
# ModuleNotFoundError: No module named 'pymysql'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
cursor.execute("SQL Query to be written here")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4130560931.py in <cell line: 0>()
# ----> 1 cursor.execute("SQL Query to be written here")
#
# NameError: name 'cursor' is not defined

# %%
# if you are using colab

import sqlite3

conn = sqlite3.connect("mydb.db")
cursor = conn.cursor()

# %%
###SELECT
    b.date,
    b.price_usd AS bitcoin_price,
    o.price_usd AS oil_price,
    s.close AS sp500_close
FROM crypto_prices b
JOIN oil_prices o ON b.date = o.date
JOIN stock_prices s ON b.date = s.date
WHERE b.coin_id = 'bitcoin'
AND s.ticker = '^GSPC';
# Out:
#   File "/tmp/ipython-input-3134170915.py", line 2
#     b.date,
#     ^
# IndentationError: unexpected indent
